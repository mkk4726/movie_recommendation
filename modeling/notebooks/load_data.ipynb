# %%
import sys
import os

# 주피터 노트북 환경에서 __file__이 없으므로, 현재 워킹 디렉토리 기준으로 설정
project_root = os.path.abspath(os.path.join(os.getcwd(), '..', '..'))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

from data_scraping.common import Config, DataStorage

config = Config()

config.DATA_DIR = '/Users/visuworks/Desktop/movie_recommendation/data_scraping/data'
storage = DataStorage(config)

# comments = storage.load_movie_comments()
# custom_ratings = storage.load_custom_rating()
infos = storage.load_movie_info()

# %%
import sys
import os

# 주피터 노트북 환경에서 __file__이 없으므로, 현재 워킹 디렉토리 기준으로 설정
project_root = os.path.abspath(os.path.join(os.getcwd(), '..', '..'))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

from data_scraping.common.data_loader import load_ratings_data, load_movie_data
    
# df_ratings = load_ratings_data()
df_movies = load_movie_data()
# Out:
# 2025-10-29 18:26:47,253 - data_scraping.common.data_storage - WARNING - Movie info file not found: ./data/movie_info_watcha.txt

# %%
df_movies
# Out:
# Empty DataFrame
# Columns: []
# Index: []
