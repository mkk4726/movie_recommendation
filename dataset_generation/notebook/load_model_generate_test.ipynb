# %%
import sys
import os

# 주피터 노트북 환경에서 __file__이 없으므로, 현재 워킹 디렉토리 기준으로 설정
project_root = os.path.abspath(os.path.join(os.getcwd(), '..', '..'))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

# %%
from dataset_generation.llm import LLM

llm = LLM()
# Out:
# `torch_dtype` is deprecated! Use `dtype` instead!

# %% [markdown]
# 1.5B 기준
# - max_token : 128 -> 10초
# - max_token : 256 -> 15초
# - max_token ; 512 -> 23초
#
# 1.5B도 나쁘지 않네. 대박이다.

# %%
# 쿼리 생성
prompt = "파이썬에서 리스트와 튜플의 차이점을 간단히 설명해줘. 한국어만 사용해"
response = llm.generate(prompt, max_new_tokens=512)

print("\n" + "="*60)
print("프롬프트:", prompt)
print("-"*60)
print("응답:", response)
print("="*60)
# Out:
# ============================================================
# 프롬프트: 파이썬에서 리스트와 튜플의 차이점을 간단히 설명해줘. 한국어만 사용해
# ------------------------------------------------------------
# 응답: 파이썬에서 리스트(LIST)와 튜플(TUPLE)은 모두 데이터를 저장하는 자료구조로, 서로 매우 유사합니다. 그러나 몇 가지 중요한 차이점이 있습니다:
#
# 1. 접근성:
#    - 리스트: 원소는 직접 인덱싱으로 접근할 수 있습니다.
#    - 튜플: 원소는 직접 인덱싱으로 접근하지 못하며, 원래 순서대로 접근해야 합니다.
#
# 2. 변경성:
#    - 리스트: 원소가 변경될 수 있습니다.
#    - 튜플: 원소가 변경될 수 없습니다.
#
# 3. 메모리 사용량:
#    - 리스트: 더 많은 메모리를 사용합니다.
#    - 튜플: 적게 메모리 사용
#
# 4. 효율성:
#    - 리스트: 속도가 빠릅니다.
#    - 튜플: 속도가 느립니다.
#
# 5. 주의사항:
#    - 리스트의 경우 추가 및 삭제 연산이 O(n) 시간 복잡도를 가집니다.
#    - 튜플의 경우 이러한 연산이 O(1) 시간 복잡도를 가집니다.
#
# 6. 활용 분야:
#    - 리스트: 큰 데이터 집합을 관리하거나 변경 가능한 상태를 유지하려는 상황에 적합합니다.
#    - 튜플: 불변적인 데이터 집합을 관리하고 싶거나 특정 순서를 유지하려는 상황에 적합합니다.
#
# 이러한 차이점 때문에, 어떤 자료 구조를 선택하는지에 따라 코드의 성능과 유지 보수성이 달라질 수 있습니다. 따라서, 적절한 자료 구조를 선택하여 코드를 작성하는 것이 중요합니다.
# ============================================================
